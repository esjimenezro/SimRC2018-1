# %% [markdown]
# # Estrategias con opciones

# %% [markdown]
# ## 0. Motivación

# %% [markdown]
# ## 1. Gráficos de profit and loss para opciones
#
# Recordemos como realizar los gráficos de ganancia/pérdida

# %% [markdown]
# ## 2. Estrategias de una opción y una acción (Sim. Montecarlo)

# %% [markdown]
# ## 3. Diferencial (alcista) de precios

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
